# %%
import numpy as np
import pandas as pd

# %%
visits = pd.read_csv('metrika_visits.csv')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_31092\2045387353.py:1: DtypeWarning: Columns (1,4,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   visits = pd.read_csv('metrika_visits.csv')

# %%
visits.columns
# Out:
# Index(['project_id', 'visit_id', 'date_time', 'is_new_user', 'client_id',
#        'region_country', 'region_city', 'watch_ids', 'traffic_source',
#        'adv_engine', 'search_engine_root', 'search_engine', 'social_network',
#        'recommendation_system', 'messenger', 'device_category', 'mobile_phone',
#        'mobile_phone_model', 'operating_system_root', 'operating_system',
#        'browser', 'browser_major_version', 'screen_width', 'screen_height'],
#       dtype='object')

# %%
import ast
if isinstance(visits['watch_ids'].iloc[0], str):
    visits['watch_ids'] = visits['watch_ids'].apply(ast.literal_eval)

# 2. Explode the list column
# This creates a row for every watch_id in the list
visits_exploded = visits.explode('watch_ids')

# 3. Rename the column for clarity and remove any nulls
visits_exploded = visits_exploded.rename(columns={'watch_ids': 'watch_id'})
visits_exploded = visits_exploded.dropna(subset=['watch_id'])

# 4. Verify the transformation
print(f"Original unique visits: {len(visits)}")
print(f"Total rows after exploding: {len(visits_exploded)}")
# Out:
# Original unique visits: 345214
# Total rows after exploding: 2902833

# %%
hits_prod = pd.read_csv('metrika_hits.csv')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_31092\799770026.py:1: DtypeWarning: Columns (1,3,19,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   hits_prod = pd.read_csv('metrika_hits.csv')

# %%
hits_prod.shape
# Out:
# (1757619, 31)

# %%
hits_prod['date_time'] = pd.to_datetime(hits_prod['date_time'], format='ISO8601')
visits['date_time'] = pd.to_datetime(visits['date_time'], format='ISO8601')
hits_prod = hits_prod.sort_values('date_time')
visits = visits.sort_values('date_time')

# %%
visits.drop(columns=['project_id'], inplace=True)

# %%
# 2. Sort both DataFrames by the timestamp
enriched_hits = pd.merge_asof(hits_prod.sort_values('date_time'), 
                       visits.sort_values('date_time').rename(columns={'date_time': 'v_date_time'}), 
                       left_on='date_time', right_on='v_date_time', by='client_id', 
                       direction='backward', tolerance=pd.Timedelta('2h'))

# %%
enriched_hits.columns
# Out:
# Index(['project_id', 'watch_id', 'date_time', 'client_id', 'region_country_x',
#        'region_city_x', 'url', 'page_type', 'slug', 'artificial',
#        'is_page_view', 'not_bounce', 'link', 'download', 'last_traffic_source',
#        'last_search_engine_root', 'last_search_engine', 'last_adv_engine',
#        'last_social_network', 'last_social_network_profile',
#        'recommendation_system_x', 'messenger_x', 'device_category_x',
#        'mobile_phone_x', 'mobile_phone_model_x', 'operating_system_root_x',
#        'operating_system_x', 'browser_x', 'browser_major_version_x',
#        'screen_width_x', 'screen_height_x', 'visit_id', 'v_date_time',
#        'is_new_user', 'region_country_y', 'region_city_y', 'watch_ids',
#        'traffic_source', 'adv_engine', 'search_engine_root', 'search_engine',
#        'social_network', 'recommendation_system_y', 'messenger_y',
#        'device_category_y', 'mobile_phone_y', 'mobile_phone_model_y',
#        'operating_system_root_y', 'operating_system_y', 'browser_y',
#        'browser_major_version_y', 'screen_width_y', 'screen_height_y'],
#       dtype='object')

# %%
# hits_new = hits[hits['project_id'] == 0]
# hits_new

# %%
# hits_prod = hits[hits['page_type'] == 'PRODUCT']
# hits_prod

# %%
hits_prod['client_id'].isin(visits_exploded['client_id']).sum()
# Out:
# 1622059

# %%
hits_prod.columns
# Out:
# Index(['project_id', 'watch_id', 'date_time', 'client_id', 'region_country',
#        'region_city', 'url', 'page_type', 'slug', 'artificial', 'is_page_view',
#        'not_bounce', 'link', 'download', 'last_traffic_source',
#        'last_search_engine_root', 'last_search_engine', 'last_adv_engine',
#        'last_social_network', 'last_social_network_profile',
#        'recommendation_system', 'messenger', 'device_category', 'mobile_phone',
#        'mobile_phone_model', 'operating_system_root', 'operating_system',
#        'browser', 'browser_major_version', 'screen_width', 'screen_height'],
#       dtype='object')

# %%
hits_prod = hits_prod.drop(columns=['region_country',
                                           'region_city', 'url','artificial', 'link', 'download', 'last_traffic_source',
                                           'last_search_engine_root', 'last_search_engine', 'last_adv_engine',
                                           'last_social_network', 'last_social_network_profile',
                                           'recommendation_system', 'messenger', 'device_category', 'mobile_phone',
                                           'mobile_phone_model', 'operating_system_root', 'operating_system',
                                           'browser', 'browser_major_version', 'screen_width', 'screen_height'], axis=1)

# %%
old_site_p = pd.read_csv('old_site_products.csv')
new_site_p = pd.read_csv('new_site_products.csv')
cols_to_keep = ['id', 'name', 'brand', 'main_category', 'categories', 'slug']
old_site_p = old_site_p[cols_to_keep]
new_site_p = new_site_p[cols_to_keep]

# %%
mapping = pd.read_csv('old_site_new_site_products.csv')

# %%
enriched_hits['slug'].isin(old_site_p['slug']).sum()
# Out:
# 387950

# %%
new_slug_to_pid = dict(zip(new_site_p['slug'], new_site_p['id']))
cat_to_pid = dict(zip(new_site_p['main_category'], new_site_p['id']))
brand_to_pid = dict(zip(new_site_p['brand'], new_site_p['id']))
old_slug_to_pid = dict(zip(old_site_p['slug'], old_site_p['id']))

# %%
def map_product_id(row):
    if row['project_id'] == 1:
        # Use the old site dictionary
        return old_slug_to_pid.get(row['slug'])
    else:
        # Use the new site dictionary (default for project_id 0)
        return new_slug_to_pid.get(row['slug'])

# Apply the function to create the new column
enriched_hits['product_id'] = enriched_hits.apply(map_product_id, axis=1)
enriched_hits.isna().sum()
# Out:
# project_id                           0
# watch_id                             0
# date_time                            0
# client_id                            0
# region_country_x                  7811
# region_city_x                   320244
# url                                  0
# page_type                            0
# slug                            318016
# artificial                           0
# is_page_view                         0
# not_bounce                           0
# link                                 0
# download                             0
# last_traffic_source                  0
# last_search_engine_root        1599228
# last_search_engine             1599228
# last_adv_engine                1558205
# last_social_network            1736733
# last_social_network_profile    1757589
# recommendation_system_x        1738574
# messenger_x                    1755119
# device_category_x                    0
# mobile_phone_x                  395858
# mobile_phone_model_x            389016
# operating_system_root_x           5383
# operating_system_x                5383
# browser_x                          232
# browser_major_version_x              0
# screen_width_x                       0
# screen_height_x                      0
# visit_id                        160479
# v_date_time                     160479
# is_new_user                     160479
# region_country_y                167466
# region_city_y                   422536
# watch_ids                       160479
# traffic_source                  160479
# adv_engine                      160479
# search_engine_root             1138299
# search_engine                  1138299
# social_network                 1695268
# recommendation_system_y        1743643
# messenger_y                    1752328
# device_category_y               160479
# mobile_phone_y                  503183
# mobile_phone_model_y            499050
# operating_system_root_y         165238
# operating_system_y              165238
# browser_y                       160664
# browser_major_version_y         160479
# screen_width_y                  160479
# screen_height_y                 160479
# product_id                     1273625
# dtype: int64

# %%
enriched_hits.columns
# Out:
# Index(['project_id', 'watch_id', 'date_time', 'client_id', 'region_country_x',
#        'region_city_x', 'url', 'page_type', 'slug', 'artificial',
#        'is_page_view', 'not_bounce', 'link', 'download', 'last_traffic_source',
#        'last_search_engine_root', 'last_search_engine', 'last_adv_engine',
#        'last_social_network', 'last_social_network_profile',
#        'recommendation_system_x', 'messenger_x', 'device_category_x',
#        'mobile_phone_x', 'mobile_phone_model_x', 'operating_system_root_x',
#        'operating_system_x', 'browser_x', 'browser_major_version_x',
#        'screen_width_x', 'screen_height_x', 'visit_id', 'v_date_time',
#        'is_new_user', 'region_country_y', 'region_city_y', 'watch_ids',
#        'traffic_source', 'adv_engine', 'search_engine_root', 'search_engine',
#        'social_network', 'recommendation_system_y', 'messenger_y',
#        'device_category_y', 'mobile_phone_y', 'mobile_phone_model_y',
#        'operating_system_root_y', 'operating_system_y', 'browser_y',
#        'browser_major_version_y', 'screen_width_y', 'screen_height_y',
#        'product_id'],
#       dtype='object')

# %%
enriched_hits.dropna(subset=['product_id'], inplace=True)
enriched_hits.drop(columns=['region_country_x',
       'region_city_x', 'url', 'artificial',
       'is_page_view', 'not_bounce', 'link', 'download', 'last_traffic_source',
       'last_search_engine_root', 'last_search_engine', 'last_adv_engine',
       'last_social_network', 'last_social_network_profile',
       'recommendation_system_x', 'messenger_x', 'device_category_x',
       'mobile_phone_x', 'mobile_phone_model_x', 'operating_system_root_x',
       'operating_system_x', 'browser_x', 'browser_major_version_x',
       'screen_width_x', 'screen_height_x', 'is_new_user', 'region_country_y', 'region_city_y', 'traffic_source', 'adv_engine', 'search_engine_root', 'search_engine',
       'social_network', 'recommendation_system_y', 'messenger_y',
       'device_category_y', 'mobile_phone_y', 'mobile_phone_model_y',
       'operating_system_root_y', 'operating_system_y', 'browser_y',
       'browser_major_version_y', 'screen_width_y', 'screen_height_y'], inplace=True)

# %%
enriched_hits.columns
# Out:
# Index(['project_id', 'watch_id', 'date_time', 'client_id', 'page_type', 'slug',
#        'visit_id', 'v_date_time', 'watch_ids', 'product_id'],
#       dtype='object')

# %%
len(enriched_hits['product_id'].unique())
# Out:
# 1208

# %%
old_to_new_map = dict(zip(mapping['old_site_id'], mapping['new_site_id']))

# If the hit was on the old site, translate the ID to the new site equivalent
def translate_to_new(row):
    if row['product_id'] <= 10000: # Old site
        return old_to_new_map.get(row['product_id'])
    return row['product_id'] # Already a new site ID or NaN

enriched_hits['product_id'] = enriched_hits.apply(translate_to_new, axis=1)
enriched_hits.isna().sum()
# Out:
# project_id         0
# watch_id           0
# date_time          0
# client_id          0
# page_type          0
# slug               0
# visit_id       50214
# v_date_time    50214
# watch_ids      50214
# product_id     77131
# dtype: int64

# %%
len(enriched_hits['product_id'].unique())
# Out:
# 595

# %%
hits_prod = hits_prod.dropna()
hits_prod.isna().sum()
# Out:
# project_id      0
# watch_id        0
# date_time       0
# client_id       0
# page_type       0
# slug            0
# is_page_view    0
# not_bounce      0
# product_id      0
# dtype: int64

# %%
visits_exploded = visits_exploded.sort_values('date_time')

# %%
hits_prod['client_id'].isin(visits_exploded['client_id']).sum()
# Out:
# 369644

# %%
hits_prod.shape
# Out:
# (406863, 9)

# %%
hits_prod['date_time'] = pd.to_datetime(hits_prod['date_time'], format='ISO8601')
visits['date_time'] = pd.to_datetime(visits['date_time'], format='ISO8601')
hits_prod = hits_prod.sort_values('date_time')
visits = visits.sort_values('date_time')

# %%
visits_exploded.columns
# Out:
# Index(['project_id', 'visit_id', 'date_time', 'is_new_user', 'client_id',
#        'region_country', 'region_city', 'watch_id', 'traffic_source',
#        'adv_engine', 'search_engine_root', 'search_engine', 'social_network',
#        'recommendation_system', 'messenger', 'device_category', 'mobile_phone',
#        'mobile_phone_model', 'operating_system_root', 'operating_system',
#        'browser', 'browser_major_version', 'screen_width', 'screen_height'],
#       dtype='object')

# %%
hits_prod['date_time'].isin(visits['date_time']).sum()
# Out:
# 58779

# %%
enriched_hits.isna().sum()
# Out:
# project_id         0
# watch_id           0
# date_time          0
# client_id          0
# page_type          0
# slug               0
# visit_id       50214
# v_date_time    50214
# watch_ids      50214
# product_id     77131
# dtype: int64

# %%
enriched_hits
# Out:
#          project_id             watch_id           date_time  \
# 0                 1  8194662451870622352 2021-11-24 00:06:51
# 8                 1  3903280002174288649 2021-11-24 00:10:02
# 9                 1  9770649425757685972 2021-11-24 00:10:02
# 39                1  7364232730061419812 2021-11-24 00:19:00
# 58                1  5753438934621470026 2021-11-24 00:27:46
# ...             ...                  ...                 ...
# 1757609           0  4908823855128880943 2025-10-14 23:51:28
# 1757610           0  4130342166892779103 2025-10-14 23:52:11
# 1757611           0  4667916384331120356 2025-10-14 23:52:11
# 1757612           0  2207112052766400320 2025-10-14 23:52:12
# 1757613           0  1746472391379054058 2025-10-14 23:52:12
#
#                    client_id page_type  \
# 0        0203466395347938108   PRODUCT
# 8        1507358969798591332   PRODUCT
# 9        1507358969798591332   PRODUCT
# 39       2582971769634308946   PRODUCT
# 58       8780827117250449029   PRODUCT
# ...                      ...       ...
# 1757609  1266192683508496743   PRODUCT
# 1757610  1266192683508496743   PRODUCT
# 1757611  1266192683508496743   PRODUCT
# 1757612  1266192683508496743   PRODUCT
# 1757613  1266192683508496743   PRODUCT
#
#                                                       slug  \
# 0                   igrovoy-derevyannyy-stolik-elc-bolshoy
# 8                               radionyanya-motorola-mbp16
# 9                               radionyanya-motorola-mbp16
# 39                                       begovel-puky-lr-m
# 58       kolyaska-2-v-1-chicco-best-friend-crossover-si...
# ...                                                    ...
# 1757609          detskaya-kolyaska-babyzen-yoyo-6-naprokat
# 1757610          detskaya-kolyaska-babyzen-yoyo-0-naprokat
# 1757611          detskaya-kolyaska-babyzen-yoyo-0-naprokat
# 1757612          detskaya-kolyaska-babyzen-yoyo-0-naprokat
# 1757613          detskaya-kolyaska-babyzen-yoyo-0-naprokat
#
#                     visit_id         v_date_time  \
# 0        8194662451870622352 2021-11-24 00:06:51
# 8        5420922249421956816 2021-11-24 00:09:52
# 9        5420922249421956816 2021-11-24 00:09:52
# 39       4293814835875824989 2021-11-24 00:15:52
# 58       1806891312327794091 2021-11-24 00:25:47
# ...                      ...                 ...
# 1757609  1024246229956678194 2025-10-14 23:50:54
# 1757610  1024246229956678194 2025-10-14 23:50:54
# 1757611  1024246229956678194 2025-10-14 23:50:54
# 1757612  1024246229956678194 2025-10-14 23:50:54
# 1757613  1024246229956678194 2025-10-14 23:50:54
#
#                                                  watch_ids   product_id
# 0                                    [8194662451870622352]          NaN
# 8        [5420922249421956816, 0133574988465249163, 463...  495364166.0
# 9        [5420922249421956816, 0133574988465249163, 463...  495364166.0
# 39       [4293814835875824989, 5616571430564964049, 736...  463480381.0
# 58       [1806891312327794091, 6042756616319257047, 780...  495400602.0
# ...                                                    ...          ...
# 1757609  [1024246229956678194, 3276733158515641412, 328...  463480227.0
# 1757610  [1024246229956678194, 3276733158515641412, 328...  463480226.0
# 1757611  [1024246229956678194, 3276733158515641412, 328...  463480226.0
# 1757612  [1024246229956678194, 3276733158515641412, 328...  463480226.0
# 1757613  [1024246229956678194, 3276733158515641412, 328...  463480226.0
#
# [483994 rows x 10 columns]

# %%
enriched_hits[enriched_hits['visit_id'] == '5420922249421956816']
# Out:
#    project_id             watch_id           date_time            client_id  \
# 8           1  3903280002174288649 2021-11-24 00:10:02  1507358969798591332
# 9           1  9770649425757685972 2021-11-24 00:10:02  1507358969798591332
#
#   page_type                        slug             visit_id  \
# 8   PRODUCT  radionyanya-motorola-mbp16  5420922249421956816
# 9   PRODUCT  radionyanya-motorola-mbp16  5420922249421956816
#
#           v_date_time                                          watch_ids  \
# 8 2021-11-24 00:09:52  [5420922249421956816, 0133574988465249163, 463...
# 9 2021-11-24 00:09:52  [5420922249421956816, 0133574988465249163, 463...
#
#     product_id
# 8  495364166.0
# 9  495364166.0

# %%
enriched_hits['product_id'].drop_duplicates(inplace=True)
enriched_hits.shape
# Out:
# (483994, 10)

# %%
enriched_hits.columns
# Out:
# Index(['project_id_x', 'watch_id', 'date_time', 'client_id', 'page_type',
#        'slug', 'is_page_view', 'not_bounce', 'product_id', 'project_id_y',
#        'visit_id', 'v_date_time', 'is_new_user', 'region_country',
#        'region_city', 'watch_ids', 'traffic_source', 'adv_engine',
#        'search_engine_root', 'search_engine', 'social_network',
#        'recommendation_system', 'messenger', 'device_category', 'mobile_phone',
#        'mobile_phone_model', 'operating_system_root', 'operating_system',
#        'browser', 'browser_major_version', 'screen_width', 'screen_height'],
#       dtype='object')

# %%
enriched_hits = enriched_hits.drop(columns=['v_date_time', 'is_new_user', 'region_country', 'region_city', 'traffic_source', 'adv_engine',
                                       'search_engine_root', 'search_engine', 'social_network',
                                       'recommendation_system', 'messenger', 'device_category', 'mobile_phone',
                                       'mobile_phone_model', 'operating_system_root', 'operating_system',
                                       'browser', 'browser_major_version', 'screen_width', 'screen_height'], axis=1)

# %%
enriched_hits
# Out:
#         project_id_x             watch_id           date_time  \
# 0                  1  3903280002174288649 2021-11-24 00:10:02
# 1                  1  9770649425757685972 2021-11-24 00:10:02
# 2                  1  7364232730061419812 2021-11-24 00:19:00
# 3                  1  5753438934621470026 2021-11-24 00:27:46
# 4                  1  9519649403537174288 2021-11-24 00:44:47
# ...              ...                  ...                 ...
# 406858             0  4908823855128880943 2025-10-14 23:51:28
# 406859             0  4130342166892779103 2025-10-14 23:52:11
# 406860             0  4667916384331120356 2025-10-14 23:52:11
# 406861             0  2207112052766400320 2025-10-14 23:52:12
# 406862             0  1746472391379054058 2025-10-14 23:52:12
#
#                   client_id page_type  \
# 0       1507358969798591332   PRODUCT
# 1       1507358969798591332   PRODUCT
# 2       2582971769634308946   PRODUCT
# 3       8780827117250449029   PRODUCT
# 4       6063184005562431269   PRODUCT
# ...                     ...       ...
# 406858  1266192683508496743   PRODUCT
# 406859  1266192683508496743   PRODUCT
# 406860  1266192683508496743   PRODUCT
# 406861  1266192683508496743   PRODUCT
# 406862  1266192683508496743   PRODUCT
#
#                                                      slug  is_page_view  \
# 0                              radionyanya-motorola-mbp16             1
# 1                              radionyanya-motorola-mbp16             1
# 2                                       begovel-puky-lr-m             1
# 3       kolyaska-2-v-1-chicco-best-friend-crossover-si...             1
# 4                          elektronnye-kacheli-mamaroo-30             1
# ...                                                   ...           ...
# 406858          detskaya-kolyaska-babyzen-yoyo-6-naprokat             0
# 406859          detskaya-kolyaska-babyzen-yoyo-0-naprokat             1
# 406860          detskaya-kolyaska-babyzen-yoyo-0-naprokat             0
# 406861          detskaya-kolyaska-babyzen-yoyo-0-naprokat             0
# 406862          detskaya-kolyaska-babyzen-yoyo-0-naprokat             0
#
#         not_bounce   product_id  project_id_y             visit_id  \
# 0                0  495364166.0           1.0  5420922249421956816
# 1                0  495364166.0           1.0  5420922249421956816
# 2                0  463480381.0           1.0  4293814835875824989
# 3                0  495400602.0           1.0  1806891312327794091
# 4                0  463480463.0           1.0  9519649403537174288
# ...            ...          ...           ...                  ...
# 406858           0  463480227.0           0.0  1024246229956678194
# 406859           0  463480226.0           0.0  1024246229956678194
# 406860           0  463480226.0           0.0  1024246229956678194
# 406861           0  463480226.0           0.0  1024246229956678194
# 406862           0  463480226.0           0.0  1024246229956678194
#
#                                                 watch_ids
# 0       [5420922249421956816, 0133574988465249163, 463...
# 1       [5420922249421956816, 0133574988465249163, 463...
# 2       [4293814835875824989, 5616571430564964049, 736...
# 3       [1806891312327794091, 6042756616319257047, 780...
# 4                                   [9519649403537174288]
# ...                                                   ...
# 406858  [1024246229956678194, 3276733158515641412, 328...
# 406859  [1024246229956678194, 3276733158515641412, 328...
# 406860  [1024246229956678194, 3276733158515641412, 328...
# 406861  [1024246229956678194, 3276733158515641412, 328...
# 406862  [1024246229956678194, 3276733158515641412, 328...
#
# [406863 rows x 12 columns]

# %%
enriched_hits = hits_prod.merge(
    visits[['date_time', 'visit_id']], 
    on='date_time', 
    how='inner'
)
enriched_hits.shape
# Out:
# (59152, 10)

# %%
enriched_hits.isna().sum()
# Out:
# project_id      0
# watch_id        0
# date_time       0
# client_id       0
# page_type       0
# slug            0
# is_page_view    0
# not_bounce      0
# product_id      0
# visit_id        0
# dtype: int64

# %%
len(enriched_hits['product_id'].unique())
# Out:
# 516

# %%
enriched_hits = enriched_hits.sort_values(['visit_id', 'date_time'])

# 2. Group into lists of sequences
sequences = enriched_hits.groupby('visit_id').agg({'product_id': list})
sequences
# Out:
#                                                              product_id
# visit_id
# 12762478139494        [495492744.0, nan, 495493530.0, 495492744.0, n...
# 31960843868541        [495368878.0, 495368878.0, 495507034.0, 495507...
# 150447116176660       [495250885.0, 495250885.0, 495250885.0, 495250...
# 194561822133345                 [463480553.0, 463480553.0, 463480589.0]
# 301432419943766                 [495400618.0, 495400618.0, 495400618.0]
# ...                                                                 ...
# 9999168946251644290                                       [495529087.0]
# 99993986280672043165                         [495514529.0, 495514529.0]
# 9999431836130268904   [495399975.0, nan, nan, nan, 463480350.0, 4634...
# 9999467905463844580                [nan, nan, 463480444.0, 463480444.0]
# 9999822896364437241                                       [495520116.0]
#
# [129505 rows x 1 columns]

# %%
sequences['product_id'] = sequences[sequences['product_id'].apply(lambda x: len(x) >= 2)]

# %%
sequences
# Out:
#                                       product_id
# visit_id
# 12762478139494                               NaN
# 194561822133345                              NaN
# 301432419943766       [495400618.0, 495400618.0]
# 405728205807658                              NaN
# 458153696400432                              NaN
# ...                                          ...
# 9998791523963942759                          NaN
# 9999057989015655840                          NaN
# 9999110073398160389                          NaN
# 9999368854516734987                          NaN
# 99993986280672043165  [495514529.0, 495514529.0]
#
# [47738 rows x 1 columns]

# %%
sequences.dropna(inplace=True)

# %%
sequences
# Out:
#                                                              product_id
# visit_id
# 301432419943766                              [495400618.0, 495400618.0]
# 5752194199488316                             [463480693.0, 463480693.0]
# 12811461182753779                            [463480226.0, 463480226.0]
# 19785702398655900                            [495400314.0, 495400314.0]
# 20851335427453159     [463480256.0, 463480256.0, 463480256.0, 463480...
# ...                                                                 ...
# 9980374974803036646                          [463480242.0, 463480242.0]
# 9982771101523665364                          [463480497.0, 463480497.0]
# 9988715156365526448                          [463480697.0, 463480697.0]
# 999050729746439619                           [495399700.0, 495399700.0]
# 99993986280672043165                         [495514529.0, 495514529.0]
#
# [7506 rows x 1 columns]

# %%
sequences.to_csv('co-occurence_sequences.csv')

# %%
len(enriched_hits['slug'].unique())
# Out:
# 729

# %%
old_new_concat = pd.concat([old_site_p, new_site_p])
old_new_concat
# Out:
#              id                                             name  \
# 0          3259            Автокресло Baby Care BSO Sport Isofix
# 1          3261             Автокресло Chicco Key1 X-Plus ISOFIX
# 2          3262              Автокресло Chicco Synthesis XT-Plus
# 3          3265                   Дом-палатка с туннелем «Океан»
# 4          3267                              Барабан для малышей
# ..          ...                                              ...
# 683  1651502137                     Адаптеры для автолюльки Yoyo
# 684  1655011689  Электрокачели MamaRoo NEW + весы Maman напрокат
# 685  1677458905                    Обезьянка на кольцах напрокат
# 686  1677460825  Развивающая игрушка "Маленькие друзья" напрокат
# 687  1678176625                     Манеж-кровать Зебра напрокат
#
#              brand        main_category  \
# 0        Baby Care           Автокресла
# 1           Chicсo           Автокресла
# 2           Chicсo           Автокресла
# 3      Ching-Ching     Домики и палатки
# 4      Imaginarium                  NaN
# ..             ...                  ...
# 683        BabyZen              Коляски
# 684   Maman##4moms         Акции недели
# 685  Bright Starts  Музыкальные игрушки
# 686   Fisher-Price  Музыкальные игрушки
# 687      Coto Baby     Кроватки, манежи
#
#                                             categories  \
# 0              ["Автокресла","Прогулки и путешествия"]
# 1              ["Автокресла","Прогулки и путешествия"]
# 2              ["Автокресла","Прогулки и путешествия"]
# 3    ["Домики и палатки","Тренажеры и игровые компл...
# 4                                                   []
# ..                                                 ...
# 683                                        ["Коляски"]
# 684         ["Акции недели","Качели, шезлонги","Весы"]
# 685      ["Развивающие игрушки","Музыкальные игрушки"]
# 686      ["Развивающие игрушки","Музыкальные игрушки"]
# 687                               ["Кроватки, манежи"]
#
#                                                   slug
# 0                avtokreslo-baby-care-bso-sport-isofix
# 1                 avtokreslo-chicco-key1-x-plus-isofix
# 2                  avtokreslo-chicco-synthesis-xt-plus
# 3                         dom-palatka-s-tunnelem-okean
# 4                                baraban-dlya-malyshey
# ..                                                 ...
# 683                      adaptery-dlya-avtolyulki-yoyo
# 684     elektrokacheli-mamaroo-new-vesy-maman-naprokat
# 685                      obezyanka-na-koltsah-naprokat
# 686  razvivayuschaya-igrushka-malenkie-druzya-naprokat
# 687                       manezh-krovat-zebra-naprokat
#
# [1449 rows x 6 columns]

# %%
enriched_hits_merged = enriched_hits.merge(old_new_concat, on='slug', how='left')
print(enriched_hits_merged.shape)
print(enriched_hits_merged.isna().sum())
# Out:
# (194623, 15)
# project_id            0
# watch_id              0
# date_time             0
# client_id             0
# page_type             0
# slug              37429
# is_page_view          0
# not_bounce            0
# visit_id              0
# is_new_user           0
# id               142954
# name             142954
# brand            142981
# main_category    143386
# categories       142954
# dtype: int64

# %%
enriched_hits_merged['slug'] = enriched_hits_merged['slug'].fillna('UNKNOWN')
enriched_hits_merged[enriched_hits_merged['slug'] == 'UNKNOWN']
# Out:
#         project_id             watch_id            date_time  \
# 1                1  6083735844269182826  2021-12-22T22:28:59
# 2                1  4602426825534813428  2021-12-22T22:29:16
# 3                1  0540455002429536660  2021-12-22T22:29:18
# 7                1  1539290260371485224  2021-12-22T22:29:32
# 16               1  7462194755248926481  2021-12-22T22:34:01
# ...            ...                  ...                  ...
# 194583           1   797197988336218981  2025-02-02T10:01:51
# 194585           1   927761660030977473  2025-02-02T10:04:12
# 194592           1   572551366397148632  2025-02-02T10:05:27
# 194612           1   614303503581490437  2025-02-02T10:56:47
# 194613           1   402119394473776510  2025-02-02T10:57:09
#
#                   client_id page_type     slug  is_page_view  not_bounce  \
# 1       8231705439711639076      MAIN  UNKNOWN             0           1
# 2       3471885286468951795      MAIN  UNKNOWN             1           0
# 3       3471885286468951795      MAIN  UNKNOWN             1           0
# 7       3471885286468951795      MAIN  UNKNOWN             0           1
# 16       021131056973009366      MAIN  UNKNOWN             1           0
# ...                     ...       ...      ...           ...         ...
# 194583  1319473386812175951      MAIN  UNKNOWN             1           0
# 194585  8438964342739742098      MAIN  UNKNOWN             1           0
# 194592  8438964342739742098      MAIN  UNKNOWN             1           0
# 194612  3521366576396512936      CART  UNKNOWN             1           0
# 194613  3521366576396512936      MAIN  UNKNOWN             1           0
#
#                    visit_id  is_new_user  id name brand main_category  \
# 1       2514991113289479317            1 NaN  NaN   NaN           NaN
# 2       4602426825534813428            1 NaN  NaN   NaN           NaN
# 3       4602426825534813428            1 NaN  NaN   NaN           NaN
# 7       4602426825534813428            1 NaN  NaN   NaN           NaN
# 16      7462194755248926481            1 NaN  NaN   NaN           NaN
# ...                     ...          ...  ..  ...   ...           ...
# 194583   797197988336218981            1 NaN  NaN   NaN           NaN
# 194585   927761660030977473            1 NaN  NaN   NaN           NaN
# 194592   927761660030977473            1 NaN  NaN   NaN           NaN
# 194612   613818631647200492            0 NaN  NaN   NaN           NaN
# 194613   613818631647200492            0 NaN  NaN   NaN           NaN
#
#        categories
# 1             NaN
# 2             NaN
# 3             NaN
# 7             NaN
# 16            NaN
# ...           ...
# 194583        NaN
# 194585        NaN
# 194592        NaN
# 194612        NaN
# 194613        NaN
#
# [37429 rows x 15 columns]

# %%
enriched_hits_merged['date_time'] = pd.to_datetime(enriched_hits_merged['date_time'], format='ISO8601')

enriched_hits_merged = enriched_hits_merged.sort_values(['visit_id', 'date_time'])

# 2. Group by visit_id to see the sequence of URLs/Slugs
user_journeys = enriched_hits_merged.groupby(['visit_id']).agg({'slug' : list, 'id': list}).reset_index()

# 3. View a sample journey
print(user_journeys.shape)
# Out:
# (40593, 3)

# %%
user_journeys
# Out:
#                    visit_id  \
# 0          1478092229145392
# 1          3300925936098714
# 2          4215450036644604
# 3          9796208045460031
# 4         13359493122602930
# ...                     ...
# 40588  99962119119578579322
# 40589   9996514530276671627
# 40590  99968006727143760123
# 40591     99986245066202684
# 40592  99993986280672043165
#
#                                                     slug  \
# 0      [UNKNOWN, ROOT, manezhi-i-krovatki, manezhi-i-...
# 1                                     [UNKNOWN, UNKNOWN]
# 2                                   [kacheli-i-kachalki]
# 3      [UNKNOWN, ROOT, detskie-vesy, vesy-laica-ps-30...
# 4                                   [kacheli-i-kachalki]
# ...                                                  ...
# 40588  [elektrokacheli, kacheli-elektronnye-komfort-i...
# 40589      [mashina-tolokar-s-ruchkoy-range-rover-sport]
# 40590                                 [UNKNOWN, UNKNOWN]
# 40591  [UNKNOWN, razvivayuschie-igrushki, razvivayusc...
# 40592  [piratskiy-korabl-kiddieland, piratskiy-korabl...
#
#                                                       id
# 0      [nan, nan, nan, nan, 3572.0, nan, 3466.0, nan,...
# 1                                             [nan, nan]
# 2                                                  [nan]
# 3         [nan, nan, nan, 3384.0, 3384.0, nan, nan, nan]
# 4                                                  [nan]
# ...                                                  ...
# 40588                            [nan, 3544.0, nan, nan]
# 40589                                           [3602.0]
# 40590                                         [nan, nan]
# 40591  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 40592                                   [3732.0, 3732.0]
#
# [40593 rows x 3 columns]

# %%
user_journeys.drop(columns = ['id'], axis=1, inplace=True)
user_journeys
# Out:
#                    visit_id                                               slug
# 0          1478092229145392  [UNKNOWN, ROOT, manezhi-i-krovatki, manezhi-i-...
# 1          3300925936098714                                 [UNKNOWN, UNKNOWN]
# 2          4215450036644604                               [kacheli-i-kachalki]
# 3          9796208045460031  [UNKNOWN, ROOT, detskie-vesy, vesy-laica-ps-30...
# 4         13359493122602930                               [kacheli-i-kachalki]
# ...                     ...                                                ...
# 40588  99962119119578579322  [elektrokacheli, kacheli-elektronnye-komfort-i...
# 40589   9996514530276671627      [mashina-tolokar-s-ruchkoy-range-rover-sport]
# 40590  99968006727143760123                                 [UNKNOWN, UNKNOWN]
# 40591     99986245066202684  [UNKNOWN, razvivayuschie-igrushki, razvivayusc...
# 40592  99993986280672043165  [piratskiy-korabl-kiddieland, piratskiy-korabl...
#
# [40593 rows x 2 columns]

# %%
user_journeys.to_csv('user_journeys.csv', index=False)

# %%
old_slug_to_id = dict(zip(old_site_p['slug'], old_site_p['id']))
new_slug_to_id = dict(zip(new_site_p['slug'], new_site_p['id']))

# %%
merged_dict = old_slug_to_id | new_slug_to_id
len(merged_dict)
# Out:
# 1424

# %%
unique_slugs_df = pd.DataFrame(enriched_hits_merged['slug'].unique(), columns=['slug'])


unique_slugs_df['pid_is_available'] = unique_slugs_df['slug'].isin(merged_dict.keys()).astype(int)

print(unique_slugs_df.shape)
# Out:
# (729, 2)

# %%
match_count = unique_slugs_df['pid_is_available'].sum()
print(f"Matched: {match_count} / {len(unique_slugs_df)}")
# Out:
# Matched: 655 / 729

# %%
unique_slugs_df = unique_slugs_df[~unique_slugs_df['slug'].isna()]
unique_slugs_df
# Out:
#                                            slug  pid_is_available
# 0                                       UNKNOWN                 0
# 1                                          ROOT                 0
# 2                            manezhi-i-krovatki                 0
# 3                       krovatka-chicco-next2me                 1
# 4                  krovatka-manezh-chicco-zipgo                 1
# ..                                          ...               ...
# 724                      gamak-krovatka-kidwood                 1
# 725     avtokreslo-maxi-cosi-pebble-crazy-mamas                 1
# 726                                   gonki-elc                 1
# 727  mobil-druzya-iz-tropicheskogo-lesa-popugay                 1
# 728                           baraban-korol-lev                 1
#
# [729 rows x 2 columns]

# %%
unique_slugs_df.to_csv('unique_slugs_df.csv', index = False)

# %%
unique_slugs_embeddings = pd.read_csv('unique_slugs_embeddings.csv')

# %%
unique_slugs_embeddings['product_id'] = unique_slugs_embeddings['slug'].map(merged_dict)
unique_slugs_embeddings
# Out:
#      Unnamed: 0                                          slug  \
# 0             0                                          ROOT
# 1             1                            manezhi-i-krovatki
# 2             2                       krovatka-chicco-next2me
# 3             3                  krovatka-manezh-chicco-zipgo
# 4             4  skladnaya-krovatka-snuggle-nest-surround-khl
# ..          ...                                           ...
# 723         723                        gamak-krovatka-kidwood
# 724         724       avtokreslo-maxi-cosi-pebble-crazy-mamas
# 725         725                                     gonki-elc
# 726         726    mobil-druzya-iz-tropicheskogo-lesa-popugay
# 727         727                             baraban-korol-lev
#
#      pid_is_available                                         embeddings  \
# 0                   0  [ 1.56962778e-02 -4.57994342e-02  1.84462667e-...
# 1                   0  [ 2.66767032e-02 -1.90703776e-02  3.84690240e-...
# 2                   1  [ 0.05553827 -0.08089578  0.03729409 -0.016796...
# 3                   1  [ 2.78634150e-02 -8.13705251e-02  6.06315248e-...
# 4                   1  [ 1.00846952e-02 -7.04894662e-02  4.13043872e-...
# ..                ...                                                ...
# 723                 1  [ 4.47303765e-02 -8.11619237e-02  1.22936862e-...
# 724                 1  [ 3.21396068e-02 -6.85035065e-02  7.52658993e-...
# 725                 1  [ 3.71554382e-02 -6.34240359e-02 -1.09364707e-...
# 726                 1  [ 3.88050713e-02 -1.89655311e-02  5.25056347e-...
# 727                 1  [ 8.80526975e-02 -5.21331877e-02  2.66078264e-...
#
#       product_id
# 0            NaN
# 1            NaN
# 2         3572.0
# 3         3466.0
# 4         3825.0
# ..           ...
# 723       3387.0
# 724       6667.0
# 725       3409.0
# 726  495519046.0
# 727       3357.0
#
# [728 rows x 5 columns]

# %%
unique_slugs_embeddings['product_id'] = unique_slugs_embeddings['product_id'].fillna(-1)
unique_slugs_embeddings

# %%
unique_slugs_embeddings.to_csv('unique_slugs_embeddings.csv', index=False)
