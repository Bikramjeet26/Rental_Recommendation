# %%
import numpy as np
import pandas as pd

# %%
hits_prod = pd.read_csv('metrika_hits.csv')
visits = pd.read_csv('metrika_visits.csv')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_29164\3309351043.py:1: DtypeWarning: Columns (1,3,19,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   hits_prod = pd.read_csv('metrika_hits.csv')
# C:\Users\user\AppData\Local\Temp\ipykernel_29164\3309351043.py:2: DtypeWarning: Columns (1,4,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   visits = pd.read_csv('metrika_visits.csv')

# %%
hits_prod['date_time'] = pd.to_datetime(hits_prod['date_time'] ,format='ISO8601')
visits['date_time'] = pd.to_datetime(visits['date_time'], format='ISO8601')

# 2. Sort both DataFrames by the timestamp
hits_prod = hits_prod.sort_values('date_time')
visits = visits.sort_values('date_time')

# 3. Perform the nearest merge
enriched_hits = pd.merge_asof(
    hits_prod, 
    visits[['visit_id', 'client_id', 'date_time']], 
    on='date_time', 
    by='client_id', 
    direction='nearest'
)
